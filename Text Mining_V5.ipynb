# %% [markdown]
# # Text Mining

# %% [markdown]
# ## Load necessary packages

# %%
from pathlib import Path
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem import SnowballStemmer
from bs4 import BeautifulSoup
from unidecode import unidecode
from tqdm import tqdm_notebook as tqdm
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
import string
import collections as ct
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import matplotlib.pyplot as plt
from nltk.stem import RSLPStemmer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
import gensim
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix
from math import ceil
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import recall_score

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import nltk
nltk.download('rslp')
# Out:
# [nltk_data] Downloading package rslp to
# [nltk_data]     C:\Users\Mafalda\AppData\Roaming\nltk_data...
# [nltk_data]   Package rslp is already up-to-date!
# True

# %% [markdown]
# ## Load corpora

# %%
def load_corpus(filename):
    corpus = Path(filename).read_text(encoding="utf8")
    return corpus

# %%
def load_corpora(filelist,author):
    files = []
    for file in filelist:
        location = "Corpora/train/"+file
        corpus = load_corpus(location)
        files.append(corpus)
    df = pd.DataFrame(files, columns=['Text'])
    df['Author'] = pd.Series([author for x in range(len(df.index))], index=df.index)
    return df

# %%
almada = [
    'AlmadaNegreiros/pg22615.txt',
    'AlmadaNegreiros/pg22730.txt',
    'AlmadaNegreiros/pg22801.txt',
    'AlmadaNegreiros/pg22802.txt',
    'AlmadaNegreiros/pg22969.txt',
    'AlmadaNegreiros/pg23133.txt',
    'AlmadaNegreiros/pg23620.txt',
    'AlmadaNegreiros/pg23879.txt',
    'AlmadaNegreiros/pg23961.txt'
]

corpora_almada = load_corpora(almada, 'Almada Negreiros')

# %%
camilo = [
    'CamiloCasteloBranco/24691-0.txt',
    'CamiloCasteloBranco/34756-0.txt',
    'CamiloCasteloBranco/pg16425.txt',
    'CamiloCasteloBranco/pg17927.txt',
    'CamiloCasteloBranco/pg19375.txt',
    'CamiloCasteloBranco/pg21406.txt',
    'CamiloCasteloBranco/pg23203.txt',
    'CamiloCasteloBranco/pg23345.txt',
    'CamiloCasteloBranco/pg23346.txt',
    'CamiloCasteloBranco/pg24339.txt',
    'CamiloCasteloBranco/pg25844.txt',
    'CamiloCasteloBranco/pg26017.txt',
    'CamiloCasteloBranco/pg26103.txt',
    'CamiloCasteloBranco/pg26110.txt',
    'CamiloCasteloBranco/pg26988.txt',
    'CamiloCasteloBranco/pg27364.txt',
    'CamiloCasteloBranco/pg27541.txt',
    'CamiloCasteloBranco/pg28310.txt',
    'CamiloCasteloBranco/pg31694.txt',
    'CamiloCasteloBranco/pg33788.txt',
]

corpora_camilo = load_corpora(camilo, 'Camilo Castelo Branco')

# %%
eca = [
    'EcaDeQueiros/pg18220.txt',
    'EcaDeQueiros/pg25641.txt',
    'EcaDeQueiros/pg27637.txt',
    'EcaDeQueiros/pg31347.txt',
    'EcaDeQueiros/pg40409.txt'
]

corpora_eca = load_corpora(eca, 'Eca de Queiros')

# %%
rodrigues_santos = [
    'JoseRodriguesSantos/A Filha Do Capitao - Jose Rodrigues dos Santos.txt',
    'JoseRodriguesSantos/A Formula De Deus - Jose Rodrigues dos Santos.txt',
    'JoseRodriguesSantos/A Mao do Diabo - Jose Rodrigues dos Santos.txt',
    'JoseRodriguesSantos/A Vida Num Sopro - Jose Rodrigues dos Santos.txt',
    'JoseRodriguesSantos/Furia Divina - Jose Rodrigues dos Santos.txt',
    'JoseRodriguesSantos/O Anjo Branco - Jose Rodrigues dos Santos.txt',
    'JoseRodriguesSantos/O Setimo Selo - Jose Rodrigues dos Santos.txt',
    'JoseRodriguesSantos/O ultimo Segredo - Jose Rodrigues dos Santos.txt'
]

corpora_rodrigues_santos = load_corpora(rodrigues_santos, 'Jose Rodrigues dos Santos')

# %%
saramago = [
    'JoseSaramago/A Caverna - Jose Saramago.txt',
    'JoseSaramago/As Intermitencias da Morte - Jose Saramago.txt',
    'JoseSaramago/Caim - Jose Saramago.txt',
    'JoseSaramago/Claraboia - Jose Saramago.txt',
    'JoseSaramago/Ensaio Sobre a Cegueira - Jose Saramago.txt',
    'JoseSaramago/Historia Do Cerco De Lisboa - Jose Saramago.txt',
    'JoseSaramago/Memorial Do Convento - Jose Saramago.txt',
    'JoseSaramago/O Ano Da Morte De Ricardo Reis - Jose Saramago.txt',
    'JoseSaramago/O Conto Da Ilha Desconhecida - Jose Saramago.txt',
    'JoseSaramago/O Homem Duplicado - Jose Saramago.txt',
    'JoseSaramago/Terra Do Pecado - Jose Saramago.txt',
    'JoseSaramago/Viagem Do Elefante - Jose Saramago.txt'
]

corpora_saramago = load_corpora(saramago, 'Jose Saramago')

# %%
luisa = [
    'LuisaMarquesSilva/ABelaHistoria.txt',
    'LuisaMarquesSilva/acabouSe.txt',
    'LuisaMarquesSilva/Botão.txt',
    'LuisaMarquesSilva/controlz.txt',
    'LuisaMarquesSilva/emedo.txt',
    'LuisaMarquesSilva/Lisboa2050.txt',
    'LuisaMarquesSilva/passeioInferno.txt',
    'LuisaMarquesSilva/rapsodiasemdo.txt',
    'LuisaMarquesSilva/UltimaHistoria.txt'
]

corpora_luisa = load_corpora(luisa, 'Luisa Marques Silva')

# %%
corpora = pd.concat([corpora_almada, corpora_camilo, corpora_eca, corpora_rodrigues_santos, corpora_saramago, corpora_luisa]).reset_index(drop = True)
corpora.head()
# Out:
#                                                 Text            Author
# 0  Title: A Scena do Odio\n\nAuthor: José de Alma...  Almada Negreiros
# 1  Title: O Jardim da Pierrette\n\nAuthor: José d...  Almada Negreiros
# 2  \n\nTitle: A Invenção do Dia Claro\n\nAuthor: ...  Almada Negreiros
# 3  \nTitle: Litoral\n       A Amadeo de Souza Car...  Almada Negreiros
# 4  \n\n\nEXPOSIÇÃO\n\n+amadeo\nde souza\ncardoso+...  Almada Negreiros

# %% [markdown]
# ## Preprocessing

# %%
def preprocessing(dataframe,accents=False,punctuation=False,lowercase=False,tags=False,stemming=False,stemmer='snowball'):
    processed_corpus = []
    
    stop_words_pt = set(stopwords.words("portuguese", "english"))
    
    for i in tqdm(range(len(dataframe))):
        text = dataframe['Text'][i]
        
        #Remove accents
        if accents:
            text = unidecode(text)
        
        #remove punctuation
        if punctuation:
            text = re.sub('[^a-zA-Z]', ' ', text)
        
        #Convert to lowercase
        if lowercase:
            text = text.lower()

        #remove tags
        if tags:
            text = BeautifulSoup(text).get_text()
        
        #Convert to list from string
        text = text.split()

        #Stemming
        if stemming:
            if stemmer == 'snowball':
                stemmer_pt = SnowballStemmer('portuguese')
            elif stemmer == 'rslp':
                stemmer_pt = RSLPStemmer()
            
            text = [stemmer_pt.stem(word) for word in text if not word in stop_words_pt]
        
        text = " ".join(text)

        processed_corpus.append(text)
    return processed_corpus

# %%
cleaned_corpora = preprocessing(corpora,stemming=True,stemmer='rslp')
# Out:
# HBox(children=(IntProgress(value=0, max=63), HTML(value='')))

# %%
corpora['Clean Text'] = pd.Series(cleaned_corpora, index = corpora.index)

# %%
corpora['Word List'] = corpora['Clean Text']

for i in tqdm(range(len(corpora))):
    mystr = corpora['Clean Text'][i]
    wordList = mystr.split()
    
    corpora['Word List'][i] = wordList
# Out:
# HBox(children=(IntProgress(value=0, max=63), HTML(value='')))

# %%
corpora
# Out:
#                                                  Text  \
# 0   Title: A Scena do Odio\n\nAuthor: José de Alma...
# 1   Title: O Jardim da Pierrette\n\nAuthor: José d...
# 2   \n\nTitle: A Invenção do Dia Claro\n\nAuthor: ...
# 3   \nTitle: Litoral\n       A Amadeo de Souza Car...
# 4   \n\n\nEXPOSIÇÃO\n\n+amadeo\nde souza\ncardoso+...
# 5   \n\n*JOSÉ DE ALMADA-NEGREIROS*\n\n\n*K4\n\no q...
# 6   \n\n*"ORPHEU"*\n\nREVISTA TRIMESTRAL DE LITERA...
# 7   \n\n+a ENGOMADEIRA+\n\nNOVELA VULGAR LISBOETA\...
# 8   \n+MANIFESTO+\n\n+ANTI-DANTAS+\n\nE\n\nPOR EXT...
# 9   O vinho do Porto\n\nPROCESSO D'UMA BESTIALIDAD...
# 10  \nLIVRO DE CONSOLAÇÃO\n\nROMANCE\n\nPOR\n\nCAM...
# 11  AMOR DE PERDIÇÃO\n\n\n(MEMORIAS D'UMA FAMILIA)...
# 12  A QUEDA D'UM ANJO\n\nROMANCE\n\nPOR\n\nCAMILLO...
# 13  \n\nA SENHORA RATTAZZI\n\nPOR\n\nCAMILLO CASTE...
# 14  \nOBRAS DE CAMILLO CASTELLO BRANCO\n\n_Novella...
# 15  SCENAS CONTEMPORANEAS\n\nPOR\n\nCAMILLO CASTEL...
# 16  A GRATIDÃO.\n\nROMANCE.\n\n\nI.\n\nEstavamos n...
# 17  O ARREPENDIMENTO.\n\nROMANCE\n\n\nEm tempos da...
# 18  SUICIDA\n\n\nPORTO Typographia de A. J. da Sil...
# 19  VOLTAREIS Ó CHRISTO?\n\n\n\n\nPorto Imprensa P...
# 20  \nROMANCES NACIONAES\n\n\nO REGICIDA\n\nRomanc...
# 21  ANNOS DE PROSA\n\nRomance\n\npor\n\nCAMILLO CA...
# 22  OBRAS\n\nDE\n\nCAMILLO CASTELLO BRANCO\n\nEDIÇ...
# 23  AMOR DE SALVAÇÃO\n\nPOR\n\nCAMILLO CASTELLO-BR...
# 24  A FILHA DO ARCEDIAGO\n\nFILHA DO ARCEDIAGO\n\n...
# 25  Obras\n\nde\n\nCamillo Castello Branco\n\nEdiç...
# 26  \nSCENAS DA FOZ\n\nPOR\n\nCAMILLO CASTELLO BRA...
# 27  \nOBRAS\n\nDE\n\nCAMILLO CASTELLO BRANCO\n\nED...
# 28  \nESTRELLAS PROPICIAS.\n\n\n\n\nOBRAS DE CAMIL...
# 29  \nA CIDADE E AS SERRAS\n\n\n\n\nA CIDADE E AS ...
# ..                                                ...
# 33  \nEÇA DE QUEIROZ\n\nOS MAIAS\n\nEPISODIOS DA V...
# 34  José Rodrigues dos Santos\n\nA Filha do Capitã...
# 35  José Rodrigues dos Santos A FÓRMULA DE DEUS\n\...
# 36  A MÃO DO D I A B O r o m a n c e\n\n\n\nNós so...
# 37  I\nO sol jorrava por todas as janelas em casca...
# 38  Prólogo\n\nAs luzes dos faróis rasgaram a noit...
# 39  JOSÉ RODRIGUES DOS SANTOS\n\nO ANJO BRANCO\n\n...
# 40  O SÉTIMO SELO romance\n\n\n © José Rodrigues d...
# 41  OBRAS DO AUTOR\n\nENSAIO Comunicação, Difusão ...
# 42  José Saramago\n\nA caverna\n\n\nRomance Novemb...
# 43  José Saramago As intermitências da morte\nComp...
# 44  JOSÉ SARAMAGO\n\nCAIM\n\nCAMINHO\n\nBadana da ...
# 45  José Saramago\n\n(Prêmio Nobel de Literatura)\...
# 46  Livro dos Conselhos\n\n\n\nO disco amarelo ilu...
# 47  José Saramago\n\nHistória do cerco de Lisboa h...
# 48  MEMORIAL DO CONVENTO José Saramago JOSÉ SARAMA...
# 49  José Saramago\n\nO ano da morte de Ricardo Rei...
# 50  José Saramago\n\nO conto da ilha desconhecida\...
# 51  O HOMEM DUPLICADO\n\nJosé Saramago\n\n***\n\nO...
# 52  José Saramago\n\nTerra do Pecado\n\nAviso\nO a...
# 53  \n a viagem do elefante obras do autor publica...
# 54  A BELA HISTÓRIA DE DINIS E BEATRIZ OU REQUIEM ...
# 55  \n\n\nAcabou-se!\nLuísa Marques da Silva\n\nTí...
# 56  O terrível caso do botão assassino\nLuísa Marq...
# 57  CONTROL Z\nChegou a hora de vos contar. Chegou...
# 58  Título\ne-medo\n\nAutora (inspiradíssima)\nLuí...
# 59  LISBOA 2050\nLisboa, ano de 2050. Um Agosto tã...
# 60  Título\nUm passeio pelo inferno\n\nAutora\nLuí...
# 61  Título\nRapsódia sem dó (maior)\n\nAutora\nLuí...
# 62  Título\nA última história\n\nAutora (próximo N...
#
#                        Author  \
# 0            Almada Negreiros
# 1            Almada Negreiros
# 24  a filh do arcediag filh do arcediag por camill...
# 25  obr camill castell branc ediç popul xxi agulh ...
# 26  scen da foz por camill castell branco. solemn ...
# 27  obr de camill castell branc ediç popul l estre...
# 28  estrell propicias. obr de camill castell branc...
# 29  a cidad e as serr a cidad e as serr i o amig j...
# ..                                                ...
# 33  eça de queiroz os mai episodi da vid roman vol...
# 34  josé rodrig sant a filh capitã josé rodrig do ...
# 35  josé rodrig sant a fórmul de deu edit record r...
# 36  a mão do d i a b o r m n c nó própri diab faz ...
# 37  i o sol jorr tod janel cascat luz, tép difusas...
# 38  prólog as luz farol rasg noit glacial, prenunc...
# 39  josé rodrig do sant o anj branc part um paraís...
# 40  o sét sel romanc © josé rodrig santos/grad — p...
# 41  obr do autor ensai comunicação, difus cultural...
# 42  josé saramag a cavern romanc novembr 2000 edit...
# 43  josé saramag as intermit mort companh letr cop...
# 44  josé saramag caim caminh badan capa: josé sara...
# 45  josé saramag (prêmi nobel literatura) clarabo ...
# 46  livr conselh o disc amarel iluminou-se. doi au...
# 47  josé saramag histór cerc lisbo http://groups.g...
# 48  memor do convent josé saramag josé saramag nas...
# 49  josé saramag o ano mort ricard reil aqu mar ac...
# 50  josé saramag o cont ilh desconhec um hom bat p...
# 51  o hom duplic josé saramag *** o hom acab entr ...
# 52  josé saramag terr pec avis o autor rapaz vint ...
# 53  viag elefant obr autor public companh letr ano...
# 54  a bel histór de dinil e beatriz ou requi por u...
# 55  acabou-se! luís marqu silv títul acabou-se! au...
# 56  o terr cas bot assassin luís marqu silv títul ...
# 57  control z cheg hor contar. cheg hor explic ra ...
# 58  títul e-med autor (inspiradíssima) luís marqu ...
# 59  lisbo 2050 lisboa, ano 2050. um agost tão gel ...
# 60  títul um passei infern autor luís marqu silv t...
# 61  títul rapsód dó (maior) autor luís marqu silv ...
# 62  títul a últ histór autor (próx nobel) luís mar...
#
#                                             Word List
# 0   [title:, a, scen, odi, author:, josé, alm, neg...
# 1   [title:, o, jardim, pierrett, author:, josé, a...
# 2   [title:, a, invenç, dia, clar, author:, josé, ...
# 3   [title:, litor, a, amade, souz, cardoz, author...
# 4   [expos, +amade, souz, cardoso+, lig, naval, de...
# 5   [*josé, de, almada-negreiros*, *k4, quadr, azu...
# 6   [*"orpheu"*, revist, trimestr, de, literat, po...
# 7   [+a, engomadeira+, novel, vulg, lisboet, +engo...
# 8   [+manifesto+, +anti-dantas+, e, por, extens, p...
# 9   [o, vinh, port, process, d'um, bestial, ingl, ...
# 10  [livr, de, consol, romanc, por, camill, castel...
# 11  [am, de, perd, (mem, d'um, familia)., romanc, ...
# 12  [a, qued, d'um, anj, romanc, por, camill, cast...
# 13  [a, senh, rattazz, por, camill, castell, branc...
# 14  [obr, de, camill, castell, branc, _novell, min...
# 15  [scen, contemporane, por, camill, castello-bra...
# 16  [a, gratidão., romance., i., estav, ult, dia, ...
# 17  [o, arrependimento., romanc, em, temp, mocidad...
# 18  [suic, port, typograph, a., j., silv, teix, ca...
# 19  [voltarel, ó, christo?, port, imprens, portugu...
# 20  [romanc, naciona, o, regic, romanc, histor, ca...
# 21  [ann, de, pros, romanc, camill, castello-branc...
# 22  [obr, de, camill, castell, branc, ediç, popul,...
# 23  [am, de, salv, por, camill, castello-branc, a,...
# 24  [a, filh, do, arcediag, filh, do, arcediag, po...
# 25  [obr, camill, castell, branc, ediç, popul, xxi...
# 26  [scen, da, foz, por, camill, castell, branco.,...
# 27  [obr, de, camill, castell, branc, ediç, popul,...
# 28  [estrell, propicias., obr, de, camill, castell...
# 29  [a, cidad, e, as, serr, a, cidad, e, as, serr,...
# ..                                                ...
# 33  [eça, de, queiroz, os, mai, episodi, da, vid, ...
# 34  [josé, rodrig, sant, a, filh, capitã, josé, ro...
# 35  [josé, rodrig, sant, a, fórmul, de, deu, edit,...
# 36  [a, mão, do, d, i, a, b, o, r, m, n, c, nó, pr...
# 37  [i, o, sol, jorr, tod, janel, cascat, luz,, té...
# 38  [prólog, as, luz, farol, rasg, noit, glacial,,...
# 39  [josé, rodrig, do, sant, o, anj, branc, part, ...
# 40  [o, sét, sel, romanc, ©, josé, rodrig, santos/...
# 41  [obr, do, autor, ensai, comunicação,, difus, c...
# 42  [josé, saramag, a, cavern, romanc, novembr, 20...
# 43  [josé, saramag, as, intermit, mort, companh, l...
# 44  [josé, saramag, caim, caminh, badan, capa:, jo...
# 45  [josé, saramag, (prêmi, nobel, literatura), cl...
# 46  [livr, conselh, o, disc, amarel, iluminou-se.,...
# 47  [josé, saramag, histór, cerc, lisbo, http://gr...
# 48  [memor, do, convent, josé, saramag, josé, sara...
# 49  [josé, saramag, o, ano, mort, ricard, reil, aq...
# 50  [josé, saramag, o, cont, ilh, desconhec, um, h...
# 51  [o, hom, duplic, josé, saramag, ***, o, hom, a...
# 52  [josé, saramag, terr, pec, avis, o, autor, rap...
# 53  [viag, elefant, obr, autor, public, companh, l...
# 54  [a, bel, histór, de, dinil, e, beatriz, ou, re...
# 55  [acabou-se!, luís, marqu, silv, títul, acabou-...
# 56  [o, terr, cas, bot, assassin, luís, marqu, sil...
# 57  [control, z, cheg, hor, contar., cheg, hor, ex...
# 58  [títul, e-med, autor, (inspiradíssima), luís, ...
# 59  [lisbo, 2050, lisboa,, ano, 2050., um, agost, ...
# 60  [títul, um, passei, infern, autor, luís, marqu...
# 61  [títul, rapsód, dó, (maior), autor, luís, marq...
# 62  [títul, a, últ, histór, autor, (próx, nobel), ...
#
# [63 rows x 4 columns]

# %%
corpora_500 = pd.DataFrame(columns=['Author','500 Word List','500 Clean Text'])

for i in tqdm(range(len(corpora))):
    text = corpora['Word List'][i]
    list_500 = [text[i:i+500] for i in range(0, len(text), 500)]
    text_500 = [" ".join(list) for list in list_500]
    
    d_500 = pd.DataFrame({'Author':corpora['Author'][i],'500 Word List':list_500,'500 Clean Text':text_500})
    corpora_500 = corpora_500.append(d_500,ignore_index=True)
    
corpora_500
# Out:
# 18    esforç desenvencilhar-s atilh proclam independ...
# 19    valores, interess form geral resolve-s exced q...
# 20    igual mim aind sab quadr azul. se és deu porqu...
# 21    desord plo contin sec morte! que form lêsm seg...
# 22    viv k4 brav salv mort terr estamp rach mart fu...
# 23    *"orpheu"* revist trimestr de literat portug e...
# 24    de_ orpheu_. ist explic ansiedad essencia! est...
# 25    intermédias, e segu crist inquietação, a retin...
# 26    mar á beira... --p sôbr eu ha grand pont que o...
# 27    volup outr ros só ser unic levant sorris pedr ...
# 28    viv outr' menos triste. ao entardec fiava, sen...
# 29    d'est janella, debruçando-me, pud deix ver mon...
# ...                                                 ...
# 4207  noit cas metad graça. par ser franca, met medo...
# 4208  antóni rodrig assunto: ond estás? vá lá, respo...
# 4209  leon rodrig para: antóni rodrig assunto: o tel...
# 4210  não pod ser coincidência. é demasiado... e acr...
# 4211  19h 00m de: leon rodrig para: antóni rodrig as...
# 4212  dad situação, avis vou emb dia ced cheg amanhã...
# 4213  normal. a ritm carec daqu doi dias. é mau. mui...
# 4214  rodrig assunto: re: responde, favor… > leonor,...
# 4215  lisbo 2050 lisboa, ano 2050. um agost tão gel ...
# 4216  família. e agora, ano arrum cas alfredo, cont ...
# 4217  fic surpreendidos, tamanh parecenças. − qu vol...
# 4218  maior. eu peç desculpa. os políci refil explic...
# 4219  guichet. − sou eu, − levant atordo − parec vez...
# 4220  títul um passei infern autor luís marqu silv t...
# 4221  quente. apavorada, sent cord esmag ossos. grit...
# 4222  títul rapsód dó (maior) autor luís marqu silv ...
# 4223  mas céu continu cinzento. cinzent escuro. nem ...
# 4224  conduz-nos, decidido, arrecadação, tras café, ...
# 4225  empurrou-m mim orc trá caixotes, ond escond ta...
# 4226  no europ 2000. dei-lh melhor pontapé. a cabeç ...
# 4227  descrev permitiram-m conclu crianç abert nov e...
# 4228  títul a últ histór autor (próx nobel) luís mar...
# 4229  − ras porc − vivia. por volt dez trint organ f...
# 4230  avent final felizes. “se autóps revel pint cab...
# 4231  pod cas lo custódia. assim, heró deix ser josé...
# 4232  josé carl cham atenç pres gem horrendo: − cúmp...
# 4233  herói. aind cima, sempr pod aproveit acrescent...
# 4234  ruiv fabíola, guinch horrorizada. o queix insp...
# 4235  ric trabalhado, ouro, muit pérol muit jóias. a...
# 4236                            corpo. dor. o corp cai.
#
# [4237 rows x 3 columns]

# %%
corpora = corpora_500

# %%
word_count = corpora['500 Clean Text'].apply(lambda x: len(str(x).split(" ")))
corpora['word_count_clean'] = word_count

corpora
# Out:
#                    Author                                      500 Word List  \
# 0        Almada Negreiros  [title:, a, scen, odi, author:, josé, alm, neg...
# 1        Almada Negreiros  [branc, par, vict, torneios-lot, donzellas-glo...
# 2        Almada Negreiros  [lua, enxovalh, vir, lavadeira!, larg, cidad, ...
# 3        Almada Negreiros  [title:, o, jardim, pierrett, author:, josé, a...
# 4        Almada Negreiros  [title:, a, invenç, dia, clar, author:, josé, ...
# 25    intermédias, e segu crist inquietação, a retin...               500
# 26    mar á beira... --p sôbr eu ha grand pont que o...               500
# 27    volup outr ros só ser unic levant sorris pedr ...               500
# 28    viv outr' menos triste. ao entardec fiava, sen...               500
# 29    d'est janella, debruçando-me, pud deix ver mon...               500
# ...                                                 ...               ...
# 4207  noit cas metad graça. par ser franca, met medo...               500
# 4208  antóni rodrig assunto: ond estás? vá lá, respo...               500
# 4209  leon rodrig para: antóni rodrig assunto: o tel...               500
# 4210  não pod ser coincidência. é demasiado... e acr...               500
# 4211  19h 00m de: leon rodrig para: antóni rodrig as...               500
# 4212  dad situação, avis vou emb dia ced cheg amanhã...               500
# 4213  normal. a ritm carec daqu doi dias. é mau. mui...               500
# 4214  rodrig assunto: re: responde, favor… > leonor,...                41
# 4215  lisbo 2050 lisboa, ano 2050. um agost tão gel ...               500
# 4216  família. e agora, ano arrum cas alfredo, cont ...               500
# 4217  fic surpreendidos, tamanh parecenças. − qu vol...               500
# 4218  maior. eu peç desculpa. os políci refil explic...               500
# 4219  guichet. − sou eu, − levant atordo − parec vez...               241
# 4220  títul um passei infern autor luís marqu silv t...               500
# 4221  quente. apavorada, sent cord esmag ossos. grit...               178
# 4222  títul rapsód dó (maior) autor luís marqu silv ...               500
# 4223  mas céu continu cinzento. cinzent escuro. nem ...               500
# 4224  conduz-nos, decidido, arrecadação, tras café, ...               500
# 4225  empurrou-m mim orc trá caixotes, ond escond ta...               500
# 4226  no europ 2000. dei-lh melhor pontapé. a cabeç ...               500
# 4227  descrev permitiram-m conclu crianç abert nov e...               195
# 4228  títul a últ histór autor (próx nobel) luís mar...               500
# 4229  − ras porc − vivia. por volt dez trint organ f...               500
# 4230  avent final felizes. “se autóps revel pint cab...               500
# 4231  pod cas lo custódia. assim, heró deix ser josé...               500
# 4232  josé carl cham atenç pres gem horrendo: − cúmp...               500
# 4233  herói. aind cima, sempr pod aproveit acrescent...               500
# 4234  ruiv fabíola, guinch horrorizada. o queix insp...               500
# 4235  ric trabalhado, ouro, muit pérol muit jóias. a...               500
# 4236                            corpo. dor. o corp cai.                 5
#
# [4237 rows x 4 columns]

# %%
corpora.groupby(['Author']).sum()
# Out:
#                            word_count_clean
# Author
# Almada Negreiros                      29835
# Camilo Castelo Branco                468084
# Eca de Queiros                       282941
# Jose Rodrigues dos Santos            708762
# Jose Saramago                        586119
# Luisa Marques Silva                   26224

# %% [markdown]
# ## Data exploration

# %%
corpora.word_count_clean.describe()
# Out:
# count    4237.000000
# mean      496.097475
# std        35.968519
# min         5.000000
# 25%       500.000000
# 50%       500.000000
# 75%       500.000000
# max       500.000000
# Name: word_count_clean, dtype: float64

# %%
all_words = ' '.join(corpora['500 Clean Text']).split()

# %%
freq = pd.Series(all_words).value_counts()

# %%
freq[:20]
# Out:
# o       14669
# tod     10142
# a        9624
# olh      7803
# outr     7728
# ser      7339
# pod      7238
# e        6698
# est      6580
# pass     6053
# aind     5967
# sab      5701
# ell      5667
# á        5523
# não      5490
# faz      5375
# ond      5052
# sobr     5020
# cas      5016
# hav      4978
# dtype: int64

# %%
stopWords = set(stopwords.words("portuguese"))
stop_words = []
for word in stopWords:
    #word = unidecode(word)
    stop_words.append(word)

# %%
count = 0

for word in freq.index[:20]:
    if word in stop_words:
        count += 1
count
# Out:
# 4

# %% [markdown]
# Only few if the most common words are stop words

# %%
def get_top_n_grams(corpus, top_k, n):
    """
    Function that receives a list of documents (corpus) and extracts
        the top k most frequent n-grams for that corpus.
        
    :param corpus: list of texts
    :param top_k: int with the number of n-grams that we want to extract
    :param n: n gram type to be considered 
             (if n=1 extracts unigrams, if n=2 extracts bigrams, ...)
             
    :return: Returns a sorted dataframe in which the first column 
        contains the extracted ngrams and the second column contains
        the respective counts
    """
    vec = CountVectorizer(ngram_range=(n, n), max_features=2000).fit(corpus)
    
    bag_of_words = vec.transform(corpus)
    
    sum_words = bag_of_words.sum(axis=0) 
    
    words_freq = []
    for word, idx in vec.vocabulary_.items():
        words_freq.append((word, sum_words[0, idx]))
        
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)
    top_df = pd.DataFrame(words_freq[:top_k])
    top_df.columns = ["Ngram", "Freq"]
    return top_df

# %%
def plot_frequencies(top_df):
    """
    Function that receives a dataframe from the "get_top_n_grams" function
    and plots the frequencies in a bar plot.
    """
    x_labels = top_df["Ngram"][:30]
    y_pos = np.arange(len(x_labels))
    values = top_df["Freq"][:30]
    plt.bar(y_pos, values, align='center', alpha=0.5)
    plt.xticks(y_pos, x_labels)
    plt.ylabel('Frequencies')
    plt.title('Words')
    plt.xticks(rotation=90)
    plt.show()

# %%
#for i in range(1,6):
#    top = get_top_n_grams(corpora["500 Clean Text"], top_k=20, n=i)
#    plot_frequencies(top)

# %% [markdown]
# From these graphics we can see that up to 2-grams we are catching expressions, but from 3-grams onwards we are just finding parts of sentences that are common but are not actual expressions that would be relevant. This is relevant because when we vectorize the texts to a Bag-of-Words or TF-IDf model we will want to catch the 2-grams but not the 3-grams.

# %% [markdown]
# ## Tests

# %%
kf = StratifiedKFold(n_splits=5,shuffle=True,random_state=42)

# %%
classifier = KNeighborsClassifier()
#classifier = MultinomialNB()
#classifier = SVC()
#classifier = DecisionTreeClassifier()
#classifier = LogisticRegression()

# %%
vectorizer = CountVectorizer(
    #max_df=0.7,
    #strip_accents='unicode',
    lowercase=False,
    #stop_words=stop_words,
    max_features=50000,
    ngram_range=(1,3)
)
vectorizer = TfidfVectorizer(
    #strip_accents='unicode',
    lowercase=False,
    #stop_words=stop_words,
    max_features=50000
)

# %%
accuracy = 0
recall = 0

for (train, test) in kf.split(corpora['500 Clean Text'],corpora['Author']):
    X_train = vectorizer.fit_transform(corpora['500 Clean Text'][train])
    X_test = vectorizer.transform(corpora['500 Clean Text'][test])
    y = corpora['Author']
    classifier.fit(X_train,y[train])
    prediction = classifier.predict(X_test)
    accuracy += accuracy_score(y[test],prediction)*100
    recall += recall_score(y[test],prediction,average=None)*100
    print(classification_report(y_true = y[test], y_pred = prediction))
    print(confusion_matrix(y_true = y[test], y_pred = prediction))
    
print(accuracy/5)
print(recall/5)
# Out:
#                            precision    recall  f1-score   support
#
#          Almada Negreiros       1.00      0.77      0.87        13
#     Camilo Castelo Branco       0.97      1.00      0.99       189
#            Eca de Queiros       1.00      0.99      1.00       114
# Jose Rodrigues dos Santos       0.99      0.99      0.99       285
#             Jose Saramago       0.99      0.99      0.99       235
#       Luisa Marques Silva       1.00      1.00      1.00        12
#
#                  accuracy                           0.99       848
#                 macro avg       0.99      0.96      0.97       848
#              weighted avg       0.99      0.99      0.99       848
#
# [[ 10   2   0   0   1   0]
#  [  0 189   0   0   0   0]
#  [  0   1 113   0   0   0]
#  [  0   2   0 282   1   0]
#  [  0   0   0   2 233   0]
#  [  0   0   0   0   0  12]]
#                            precision    recall  f1-score   support
#
#          Almada Negreiros       1.00      0.92      0.96        13
#     Camilo Castelo Branco       0.98      1.00      0.99       189
#            Eca de Queiros       1.00      0.96      0.98       114
# Jose Rodrigues dos Santos       0.99      1.00      1.00       284
#             Jose Saramago       0.99      1.00      1.00       236
#       Luisa Marques Silva       1.00      0.92      0.96        12
#
#                  accuracy                           0.99       848
#                 macro avg       0.99      0.97      0.98       848
#              weighted avg       0.99      0.99      0.99       848
#
# [[ 12   0   0   0   1   0]
#  [  0 189   0   0   0   0]
#  [  0   3 109   2   0   0]
#  [  0   0   0 284   0   0]
#  [  0   0   0   0 236   0]
#  [  0   0   0   0   1  11]]
#                            precision    recall  f1-score   support
#
#          Almada Negreiros       0.87      1.00      0.93        13
#     Camilo Castelo Branco       0.99      0.98      0.99       189
#            Eca de Queiros       0.98      0.99      0.99       114
# Jose Rodrigues dos Santos       0.99      1.00      1.00       284
#             Jose Saramago       0.99      0.99      0.99       236
#       Luisa Marques Silva       1.00      0.82      0.90        11
#
#                  accuracy                           0.99       847
#                 macro avg       0.97      0.96      0.97       847
#              weighted avg       0.99      0.99      0.99       847
#
# [[ 13   0   0   0   0   0]
#  [  1 185   2   0   1   0]
#  [  1   0 113   0   0   0]
#  [  0   0   0 284   0   0]
#  [  0   1   0   1 234   0]
#  [  0   0   0   1   1   9]]
#                            precision    recall  f1-score   support
#
#          Almada Negreiros       1.00      0.85      0.92        13
#     Camilo Castelo Branco       0.99      1.00      1.00       189
#            Eca de Queiros       1.00      0.99      1.00       114
# Jose Rodrigues dos Santos       1.00      1.00      1.00       284
#             Jose Saramago       0.99      1.00      0.99       236
#       Luisa Marques Silva       1.00      0.91      0.95        11
#
#                  accuracy                           0.99       847
#                 macro avg       1.00      0.96      0.98       847
#              weighted avg       0.99      0.99      0.99       847
#
# [[ 11   0   0   0   2   0]
#  [  0 189   0   0   0   0]
#  [  0   1 113   0   0   0]
#  [  0   0   0 284   0   0]
#  [  0   0   0   1 235   0]
#  [  0   0   0   0   1  10]]
#                            precision    recall  f1-score   support
#
#          Almada Negreiros       0.92      0.92      0.92        12
#     Camilo Castelo Branco       0.99      0.99      0.99       190
#            Eca de Queiros       1.00      0.99      1.00       113
# Jose Rodrigues dos Santos       0.98      1.00      0.99       285
#             Jose Saramago       1.00      1.00      1.00       235
#       Luisa Marques Silva       1.00      0.58      0.74        12
#
#                  accuracy                           0.99       847
#                 macro avg       0.98      0.91      0.94       847
#              weighted avg       0.99      0.99      0.99       847
#
# [[ 11   1   0   0   0   0]
#  [  1 189   0   0   0   0]
#  [  0   0 112   1   0   0]
#  [  0   0   0 284   1   0]
#  [  0   0   0   1 234   0]
#  [  0   0   0   5   0   7]]
# 99.05593548818248
# [89.1025641  99.47145642 98.41950008 99.71929825 99.49044356 84.54545455]

# %% [markdown]
# ## Train the chosen model

# %%
X = corpora['500 Clean Text']
y = corpora['Author']

X_cv = vectorizer.fit_transform(X)
classifier.fit(X_cv,y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %% [markdown]
# ## Load new text

# %%
def load_new_corpora(filelist):
    files = []
    for file in filelist:
        location = "Corpora/test/"+file
        corpus = load_corpus(location)
        files.append(corpus)
    df = pd.DataFrame(files, columns=['Text'])
    return df

# %%
files = [
    '500Palavras/text1.txt',
    '500Palavras/text2.txt',
    '500Palavras/text3.txt',
    '500Palavras/text4.txt',
    '500Palavras/text5.txt',
    '500Palavras/text6.txt',
    '1000Palavras/text1.txt',
    '1000Palavras/text2.txt',
    '1000Palavras/text3.txt',
    '1000Palavras/text4.txt',
    '1000Palavras/text5.txt',
    '1000Palavras/text6.txt',
]

new_corpora = load_new_corpora(files)

# %%
new_corpora
# Out:
#                                                  Text
# 0   Depois, pouco a pouco, a tranquilidade regress...
# 1   Justamente como se eu tivesse tido a ideia de ...
# 2   Quase um mês depois, a época de exames aproxim...
# 3   Agora, porém, era sem fervor, arrastadamente, ...
# 4   O cahos de cima a descer, a descer com a morta...
# 5   "O Senhor ensina pela pena o que o homem não s...
# 6   Depois, pouco a pouco, a tranquilidade regress...
# 7   Justamente como se eu tivesse tido a ideia de ...
# 8   Quase um mês depois, a época de exames aproxim...
# 9   Agora, porém, era sem fervor, arrastadamente, ...
# 10  O cahos de cima a descer, a descer com a morta...
# 11  "O Senhor ensina pela pena o que o homem não s...

# %%
cleaned_corpora = preprocessing(new_corpora,stemming=True,stemmer='rslp')
# Out:
# HBox(children=(IntProgress(value=0, max=12), HTML(value='')))

# %%
new_corpora['Clean Text'] = pd.Series(cleaned_corpora, index = new_corpora.index)

# %% [markdown]
# ## Classify the new text

# %%
new_cv = vectorizer.transform(new_corpora['Clean Text'])
prediction = classifier.predict(new_cv)

# %%
prediction
# Out:
# array(['Jose Saramago', 'Almada Negreiros', 'Jose Rodrigues dos Santos',
#        'Eca de Queiros', 'Camilo Castelo Branco',
#        'Jose Rodrigues dos Santos', 'Jose Saramago', 'Almada Negreiros',
#        'Jose Saramago', 'Eca de Queiros', 'Camilo Castelo Branco',
#        'Jose Rodrigues dos Santos'], dtype=object)
